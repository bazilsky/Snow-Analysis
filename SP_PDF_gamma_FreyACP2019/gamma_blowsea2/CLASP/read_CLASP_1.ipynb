# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio  # to load .mat files
plt.style.use('fivethirtyeight')

# %%
data = sio.loadmat('clasp_all_1min.mat')

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'CLASP', 'fname_op'])

# %%
x=data['CLASP']

x
# Out:
# array([[(array([[ 20.01703015,  16.47313191,  15.76314869, ..., 600.        ,
#                 600.        , 600.        ],
#                [ 23.62894593,  18.95465233,  15.81637048, ..., 600.        ,
#                 600.        , 600.        ],
#                [ 18.50398177,  11.153353  ,  12.92584435, ..., 600.        ,
#                 600.        , 600.        ],
#                ...,
#                [  0.        ,   0.        ,  17.84339543, ..., 600.        ,
#                 600.        , 600.        ],
#                [  0.        ,   0.        ,  18.70540925, ..., 600.        ,
#                 600.        , 600.        ],
#                [  0.        ,   0.        ,  21.81525436, ..., 600.        ,
#                 600.        , 600.        ]]), array([[(array([[1.15136667e+01, 5.35190974e-02, 6.00000000e+01],
#                        [1.15326667e+01, 1.92984294e-02, 6.00000000e+01],
#                        [1.15380000e+01, 1.68543109e-02, 6.00000000e+01],
# ...

# %%
# read new data file 
data2 = sio.loadmat('clasp_data.mat')

# %%
data2.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'x'])

# %%
data2['x'][]
# Out:
# array([[(array([[ 20.01703015,  16.47313191,  15.76314869, ..., 600.        ,
#                 600.        , 600.        ],
#                [ 23.62894593,  18.95465233,  15.81637048, ..., 600.        ,
#                 600.        , 600.        ],
#                [ 18.50398177,  11.153353  ,  12.92584435, ..., 600.        ,
#                 600.        , 600.        ],
#                ...,
#                [  0.        ,   0.        ,  17.84339543, ..., 600.        ,
#                 600.        , 600.        ],
#                [  0.        ,   0.        ,  18.70540925, ..., 600.        ,
#                 600.        , 600.        ],
#                [  0.        ,   0.        ,  21.81525436, ..., 600.        ,
#                 600.        , 600.        ]]), array([[(array([[1.15136667e+01, 5.35190974e-02, 6.00000000e+01],
#                        [1.15326667e+01, 1.92984294e-02, 6.00000000e+01],
#                        [1.15380000e+01, 1.68543109e-02, 6.00000000e+01],
# ...
