# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in .mat file 
import scipy.io as sio

filename = 'U1104_8cm_1min.mat'
filepath = '/Users/ananth/Desktop/bas_scripts/DATA_SETS/mosaic/newdata_with_metcity/'
mat_contents = sio.loadmat(filepath+filename)

# %%
mat_contents.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'A', 'None', 'F', 'MU', 'N', 'Ntot', 'Q', 'Qi', 'RH10m', 'RH2m', 'RH6m', 'SP_data', 'T', 'T10m', 'T10m_ex', 'T29m_PS', 'T2m', 'T6m', 'U10m', 'U10m_ex', 'U2m', 'U39m_PS', 'U6m', 'U8cm_ex', 'dp_bins', 'filename', 'fname', 'jday', 'lat', 'lon', 'meanD', 'mu', 'p', 'q', 'rho_ice', 'snow_depth', 't', 't_NOAA', '__function_workspace__'])

# %%
U10m = mat_contents['U10m_ex']
# remove all nan values
U10m = U10m[~np.isnan(U10m)]

# %%
np.max(U10m)
# Out:
# 17.769269029558693

# %%
# plot histogram of velocity data with grid in fivethirty eight style and normalised y axis
plt.figure(figsize=(12, 8))
plt.style.use('fivethirtyeight')
plt.hist(U10m, bins=100, density=True, edgecolor = 'black', linewidth=1.2, label = 'U10m MOSAIC Obs')
plt.xlabel('U10m (m/s)', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
#plt.title('Wind Speed Distribution', fontsize=20)
# plot vertical red line at 5.25m/s
plt.axvline(x=5.25, color='r', linestyle='--', linewidth=2, label = 'U_thershold = 5.25m/s')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True)
plt.legend(fontsize=18)
plt.show()

# %%
# make a cumulative distribution function of the data with y axis normalised
plt.figure(figsize=(12, 8))
plt.style.use('fivethirtyeight')
plt.hist(U10m, bins=100, density=True, cumulative=True, edgecolor = 'black', linewidth=1.2, label = 'U10m MOSAIC Obs')
plt.xlabel('U10m (m/s)', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
#plt.title('Wind Speed Distribution', fontsize=20)
# plot vertical red line at 5.25m/s
plt.axvline(x=5.25, color='r', linestyle='--', linewidth=2, label = 'U_thershold = 5.25m/s')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True)
plt.legend(fontsize=18)
